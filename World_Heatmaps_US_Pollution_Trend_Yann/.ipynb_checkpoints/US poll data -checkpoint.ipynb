# %%
#read file 
import pandas as pd
filepath = "pollution_us_2000_2016.csv"
us_pollution_data = pd.read_csv(filepath)
us_pollution_data.columns
# Out:
# Index(['Unnamed: 0', 'State Code', 'County Code', 'Site Num', 'Address',
#        'State', 'County', 'City', 'Date Local', 'NO2 Units', 'NO2 Mean',
#        'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI', 'O3 Units',
#        'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI', 'SO2 Units',
#        'SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI',
#        'CO Units', 'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI'],
#       dtype='object')

# %%
#Create Year column. which we will use to group the data by year.
Date_data = []
for i in us_pollution_data['Date Local']:
    date = i.split("-")
    year= date[0]
    Date_data.append(year)
us_pollution_data['Year'] = Date_data

#clean data by dropping rows with null values.
us_pollution_data_clean = us_pollution_data.dropna(how='any')

# %%
#Create a collection of columns of interest 
Chem_Columns = us_pollution_data_clean[['State', 'Date Local', 'Year','NO2 Units', 'NO2 Mean', 'O3 Units', 'O3 Mean','SO2 Units', 'SO2 Mean', 'CO Units', 'CO Mean']]
Chem_Columns.head()
# Out:
#      State  Date Local  Year          NO2 Units   NO2 Mean           O3 Units  \
# 0  Arizona  2000-01-01  2000  Parts per billion  19.041667  Parts per million
# 1  Arizona  2000-01-02  2000  Parts per billion  22.958333  Parts per million
# 2  Arizona  2000-01-03  2000  Parts per billion  38.125000  Parts per million
# 3  Arizona  2000-01-04  2000  Parts per billion  40.260870  Parts per million
# 4  Arizona  2000-01-05  2000  Parts per billion  48.450000  Parts per million
#
#     O3 Mean          SO2 Units  SO2 Mean           CO Units   CO Mean
# 0  0.022500  Parts per billion  3.000000  Parts per million  0.878947
# 1  0.013375  Parts per billion  1.958333  Parts per million  1.066667
# 2  0.007958  Parts per billion  5.250000  Parts per million  1.762500
# 3  0.014167  Parts per billion  7.083333  Parts per million  1.829167
# 4  0.006667  Parts per billion  8.708333  Parts per million  2.700000

# %%
test = Chem_Columns.groupby(['Year', 'State']).mean()
# test.pivot(index='State', columns='Year', values='')
# Out:
#                             NO2 Mean   O3 Mean  SO2 Mean   CO Mean
# Year State
# 2000 Arizona               26.492344  0.023664  2.297970  0.746075
#      California            17.580980  0.023675  1.730039  0.647508
#      Colorado              14.902469  0.017066  2.113657  0.615031
#      District Of Columbia  22.725717  0.017567  8.172178  1.178786
#      Florida               12.453038  0.026261  1.983244  0.726884
#      Illinois              26.437457  0.017105  6.099496  0.706236
#      Indiana               15.287580  0.029782  7.299264  0.875499
#      Kansas                 9.703852  0.029726  0.952126  0.756692
#      Kentucky              12.660981  0.028916  4.770384  0.178344
#      Louisiana             17.346074  0.023756  3.664487  0.758775
#      Michigan              22.682065  0.023367  5.420799  0.280681
