# %%
#read file 
import pandas as pd
filepath = "EXP_MORSC_01032019225444048.csv"
country_mort_data = pd.read_csv(filepath)
country_mort_data.head()
# Out:
#    COU    Country     VAR                                  Variable   YEA  \
# 0  AUS  Australia  PM_MOR  Mortality from exposure to outdoor PM2.5  1990
# 1  AUS  Australia  PM_MOR  Mortality from exposure to outdoor PM2.5  1991
# 2  AUS  Australia  PM_MOR  Mortality from exposure to outdoor PM2.5  1992
# 3  AUS  Australia  PM_MOR  Mortality from exposure to outdoor PM2.5  1993
# 4  AUS  Australia  PM_MOR  Mortality from exposure to outdoor PM2.5  1994
#
#    Year   Unit Code                       Unit  PowerCode Code PowerCode  \
# 0  1990  1000000HAB  Per 1 000 000 inhabitants               0     Units
# 1  1991  1000000HAB  Per 1 000 000 inhabitants               0     Units
# 2  1992  1000000HAB  Per 1 000 000 inhabitants               0     Units
# 3  1993  1000000HAB  Per 1 000 000 inhabitants               0     Units
# 4  1994  1000000HAB  Per 1 000 000 inhabitants               0     Units
#
#    Reference Period Code  Reference Period     Value  Flag Codes  Flags
# 0                    NaN               NaN  300.0652         NaN    NaN
# 1                    NaN               NaN  297.1893         NaN    NaN
# 2                    NaN               NaN  300.2021         NaN    NaN
# 3                    NaN               NaN  292.8972         NaN    NaN
# 4                    NaN               NaN  295.0728         NaN    NaN

# %%
# country_mort_data['Country'].value_counts()

# %%
#Filter mortality data for data relevant to the US.
US_data = country_mort_data[country_mort_data['Country'].str.contains("United States")==True]
US_data

# %%
US_data.head()
# Out:
#      COU        Country     VAR                                  Variable  \
# 812  USA  United States  PM_MOR  Mortality from exposure to outdoor PM2.5
# 813  USA  United States  PM_MOR  Mortality from exposure to outdoor PM2.5
# 814  USA  United States  PM_MOR  Mortality from exposure to outdoor PM2.5
# 815  USA  United States  PM_MOR  Mortality from exposure to outdoor PM2.5
# 816  USA  United States  PM_MOR  Mortality from exposure to outdoor PM2.5
#
#       YEA  Year   Unit Code                       Unit  PowerCode Code  \
# 812  1990  1990  1000000HAB  Per 1 000 000 inhabitants               0
# 813  1991  1991  1000000HAB  Per 1 000 000 inhabitants               0
# 814  1992  1992  1000000HAB  Per 1 000 000 inhabitants               0
# 815  1993  1993  1000000HAB  Per 1 000 000 inhabitants               0
# 816  1994  1994  1000000HAB  Per 1 000 000 inhabitants               0
#
#     PowerCode  Reference Period Code  Reference Period     Value  Flag Codes  \
# 812     Units                    NaN               NaN  372.6680         NaN
# 813     Units                    NaN               NaN  371.3994         NaN
# 814     Units                    NaN               NaN  367.1144         NaN
# 815     Units                    NaN               NaN  375.3801         NaN
# 816     Units                    NaN               NaN  373.4384         NaN
#
#      Flags
# 812    NaN
# 813    NaN
# 814    NaN
# 815    NaN
# 816    NaN

# %%
US_data_mix_var = US_data[['Country', 'Variable', 'Year', 'Unit', 'Value']]
US_data_mix_var.head()
# 5265    Per 1 000 000 inhabitants     239.5418
# ...                           ...          ...
# 98163                      Number  351772.5000
# 98164                      Number  363096.1000
# 102561                  US Dollar   38884.2300
# 102562                  US Dollar   40131.2300
# 102563                  US Dollar   42170.7500
# 102564                  US Dollar   45591.9500
# 102565                  US Dollar   48297.4600
# 102566                  US Dollar   50963.0900
# 102567                  US Dollar   53252.8300
# 102568                  US Dollar   56144.1100
# 102569                  US Dollar   59770.8600
# 102570                  US Dollar   64717.8700
# 102571                  US Dollar   67988.6500
# 102572                  US Dollar   69571.4500
# 102573                  US Dollar   71614.5200
# 102574                  US Dollar   74036.9100
# 102575                  US Dollar   75511.7000
# 102576                  US Dollar   79910.5900
# 102577                  US Dollar   81956.3800
# 102578                  US Dollar   83855.5500
# 102579                  US Dollar   85948.9100
# 102580                  US Dollar   84859.2000
# 102581                  US Dollar   86898.7000
# 102582                  US Dollar   90897.9200
# 102583                  US Dollar   93987.4500
# 102584                  US Dollar   97699.0900
# 102585                  US Dollar  101366.0000
# 102586                  US Dollar  106267.5000
# 102587                  US Dollar  109316.4000
# 102588                  US Dollar  114038.6000
#
# [840 rows x 5 columns]

# %%
#filter the "United states" data frame for variable values pertaining to mortality
Mort_data_analysis = US_data_mix_var.loc[US_data_mix_var['Variable'] == "Mortality from exposure to outdoor PM2.5", :]
#Note at this point the data still contains values for United States virgin Islands
#So we filter out the Virgin Islands and get Data for only United States 
US_PM25_Mort_data = Mort_data_analysis.loc[Mort_data_analysis['Country'] == "United States", :]


US_PM25_Mort_data.sort_values(by=['Year'])
US_PM25_Mort_data['Year'].value_counts()
# Out:
# 2017    1
# 2016    1
# 1991    1
# 1992    1
# 1993    1
# 1994    1
# 1995    1
# 1996    1
# 1997    1
# 1998    1
# 1999    1
# 2000    1
# 2001    1
# 2002    1
# 2003    1
# 2004    1
# 2005    1
# 2006    1
# 2007    1
# 2008    1
# 2009    1
# 2010    1
# 2011    1
# 2012    1
# 2013    1
# 2014    1
# 2015    1
# 1990    1
# Name: Year, dtype: int64

# %%
US_PM25_Mort_data.to_csv("../DataFrames/US_PM25_Mort_data.csv", index=False, header=True)

# %%
#potentially do a group by year then graph... the grouped us mean poll_volume levels for those year versus the number of cases for that year

#groupby year with count of number of observations for mort...

# do a line grapgh showing change in counts over years
# along side a graph of mean pollution volume over years to see if the change in mean volume is related to the 


#question: while the analysis itself makes sense.. how should we interepret the change in mean volum over time in comaprison to the mort count over time...
#simply because we have defined the mortality as resulting from air pollution 





#question: is the interpretation of correlation correct in the sense that the data does not necessarily come from the same sample?

#does it make sense you just compare a collection of data for a year with another collection of data for the same year?

# %%
#could also do an analysis of world pollution mortality counts versus world pollution level data 


#we have a world pollution data set but we just havent found a way to get into it at the moment 

# with the world pollution data set we could then run an analysis of mortality count for countries versus pollution level
#for each country 

#is each row an individual case ?

#how should we interepret the unit column?
