# %%
#read file 
import pandas as pd
filepath = "EXP_MORSC_01032019225444048.csv"
country_mort_data = pd.read_csv(filepath)
country_mort_data.head()
# Out:
#    COU    Country     VAR                                  Variable   YEA  \
# 0  AUS  Australia  PM_MOR  Mortality from exposure to outdoor PM2.5  1990
# 1  AUS  Australia  PM_MOR  Mortality from exposure to outdoor PM2.5  1991
# 2  AUS  Australia  PM_MOR  Mortality from exposure to outdoor PM2.5  1992
# 3  AUS  Australia  PM_MOR  Mortality from exposure to outdoor PM2.5  1993
# 4  AUS  Australia  PM_MOR  Mortality from exposure to outdoor PM2.5  1994
#
#    Year   Unit Code                       Unit  PowerCode Code PowerCode  \
# 0  1990  1000000HAB  Per 1 000 000 inhabitants               0     Units
# 1  1991  1000000HAB  Per 1 000 000 inhabitants               0     Units
# 2  1992  1000000HAB  Per 1 000 000 inhabitants               0     Units
# 3  1993  1000000HAB  Per 1 000 000 inhabitants               0     Units
# 4  1994  1000000HAB  Per 1 000 000 inhabitants               0     Units
#
#    Reference Period Code  Reference Period     Value  Flag Codes  Flags
# 0                    NaN               NaN  300.0652         NaN    NaN
# 1                    NaN               NaN  297.1893         NaN    NaN
# 2                    NaN               NaN  300.2021         NaN    NaN
# 3                    NaN               NaN  292.8972         NaN    NaN
# 4                    NaN               NaN  295.0728         NaN    NaN

# %% [markdown]
# # Filter Data For "United States" Data

# %%
#Filter data for data relevant to the US.
US_data = country_mort_data[country_mort_data['Country'].str.contains("United States")==True]
US_data.head()
# Out:
#      COU        Country     VAR                                  Variable  \
# 812  USA  United States  PM_MOR  Mortality from exposure to outdoor PM2.5
# 813  USA  United States  PM_MOR  Mortality from exposure to outdoor PM2.5
# 814  USA  United States  PM_MOR  Mortality from exposure to outdoor PM2.5
# 815  USA  United States  PM_MOR  Mortality from exposure to outdoor PM2.5
# 816  USA  United States  PM_MOR  Mortality from exposure to outdoor PM2.5
#
#       YEA  Year   Unit Code                       Unit  PowerCode Code  \
# 812  1990  1990  1000000HAB  Per 1 000 000 inhabitants               0
# 813  1991  1991  1000000HAB  Per 1 000 000 inhabitants               0
# 814  1992  1992  1000000HAB  Per 1 000 000 inhabitants               0
# 815  1993  1993  1000000HAB  Per 1 000 000 inhabitants               0
# 816  1994  1994  1000000HAB  Per 1 000 000 inhabitants               0
#
#     PowerCode  Reference Period Code  Reference Period     Value  Flag Codes  \
# 812     Units                    NaN               NaN  372.6680         NaN
# 813     Units                    NaN               NaN  371.3994         NaN
# 814     Units                    NaN               NaN  367.1144         NaN
# 815     Units                    NaN               NaN  375.3801         NaN
# 816     Units                    NaN               NaN  373.4384         NaN
#
#      Flags
# 812    NaN
# 813    NaN
# 814    NaN
# 815    NaN
# 816    NaN

# %% [markdown]
# # Select Relevant Column Data

# %%
US_data_mix_var = US_data[['Country', 'Variable', 'Year', 'Unit', 'Value']]
US_data_mix_var.head(5)
# Out:
#            Country                                  Variable  Year  \
# 812  United States  Mortality from exposure to outdoor PM2.5  1990
# 813  United States  Mortality from exposure to outdoor PM2.5  1991
# 814  United States  Mortality from exposure to outdoor PM2.5  1992
# 815  United States  Mortality from exposure to outdoor PM2.5  1993
# 816  United States  Mortality from exposure to outdoor PM2.5  1994
#
#                           Unit     Value
# 812  Per 1 000 000 inhabitants  372.6680
# 813  Per 1 000 000 inhabitants  371.3994
# 814  Per 1 000 000 inhabitants  367.1144
# 815  Per 1 000 000 inhabitants  375.3801
# 816  Per 1 000 000 inhabitants  373.4384

# %% [markdown]
# # Final Filter To Remove US Virgin Island Data

# %%
#filter the "United states" data frame for variable values pertaining to mortality
Mort_data_analysis = US_data_mix_var.loc[US_data_mix_var['Variable'] == "Mortality from exposure to outdoor PM2.5", :]
#Note at this point the data still contains values for United States virgin Islands
#So we filter out the Virgin Islands and get Data for only United States 
US_PM25_Mort_data = Mort_data_analysis.loc[Mort_data_analysis['Country'] == "United States", :]


US_PM25_Mort_data.sort_values(by=['Year']).head()
# Out:
#            Country                                  Variable  Year  \
# 812  United States  Mortality from exposure to outdoor PM2.5  1990
# 813  United States  Mortality from exposure to outdoor PM2.5  1991
# 814  United States  Mortality from exposure to outdoor PM2.5  1992
# 815  United States  Mortality from exposure to outdoor PM2.5  1993
# 816  United States  Mortality from exposure to outdoor PM2.5  1994
#
#                           Unit     Value
# 812  Per 1 000 000 inhabitants  372.6680
# 813  Per 1 000 000 inhabitants  371.3994
# 814  Per 1 000 000 inhabitants  367.1144
# 815  Per 1 000 000 inhabitants  375.3801
# 816  Per 1 000 000 inhabitants  373.4384

# %%
US_PM25_Mort_data.to_csv("../DataFrames/US_PM25_Mort_data.csv", index=False, header=True)
