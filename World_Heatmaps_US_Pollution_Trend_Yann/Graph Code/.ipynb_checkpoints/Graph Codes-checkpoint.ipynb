# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import gmaps
from config import gkey
gmaps.configure(api_key=gkey)

State_Chem_filepath = "../DataFrames/Chem_mean_by_State.csv"
Chem_filepath = "../DataFrames/Chem_mean_by_Year.csv"
Mort_filepath = "../DataFrames/US_PM25_Mort_data.csv"
State_Pop_filepath = "../DataFrames/State_Population.csv"
Group_ST_YR_filepath = "../DataFrames/Group_State_then_Year.csv"
World_Pollution_filepath = "../DataFrames/World_Pollution_df.csv"

Group_State_then_Year = pd.read_csv(Group_ST_YR_filepath)
Chem_by_Year = pd.read_csv(Chem_filepath)
US_PM25_Mort_data = pd.read_csv(Mort_filepath)
State_Population_df = pd.read_csv(State_Pop_filepath)
Chem_by_ST_Year = pd.read_csv(State_Chem_filepath)
World_Pollution_df = pd.read_csv(World_Pollution_filepath)

# %%
#regroup by year
Chem_by_Year.head(5)
# Out:
#    Year  NO2 Mean   O3 Mean  SO2 Mean   CO Mean  Year Average
# 0  2000  0.017433  0.024376  0.003649  0.557789      0.150812
# 1  2001  0.017600  0.025388  0.003133  0.509119      0.138810
# 2  2002  0.016387  0.026818  0.002744  0.500990      0.136735
# 3  2003  0.015865  0.025521  0.002865  0.492720      0.134243
# 4  2004  0.014968  0.024914  0.002855  0.448132      0.122717

# %%
US_PM25_Mort_data.head()
# Out:
#          Country                                  Variable  Year  \
# 0  United States  Mortality from exposure to outdoor PM2.5  1990
# 1  United States  Mortality from exposure to outdoor PM2.5  1991
# 2  United States  Mortality from exposure to outdoor PM2.5  1992
# 3  United States  Mortality from exposure to outdoor PM2.5  1993
# 4  United States  Mortality from exposure to outdoor PM2.5  1994
#
#                         Unit     Value
# 0  Per 1 000 000 inhabitants  372.6680
# 1  Per 1 000 000 inhabitants  371.3994
# 2  Per 1 000 000 inhabitants  367.1144
# 3  Per 1 000 000 inhabitants  375.3801
# 4  Per 1 000 000 inhabitants  373.4384

# %%
merge_table = pd.merge(Chem_by_Year, US_PM25_Mort_data, on="Year")

# %%
merge_table.head()
# Out:
#    Year  NO2 Mean   O3 Mean  SO2 Mean   CO Mean  Year Average        Country  \
# 0  2000  0.017433  0.024376  0.003649  0.557789      0.150812  United States
# 1  2001  0.017600  0.025388  0.003133  0.509119      0.138810  United States
# 2  2002  0.016387  0.026818  0.002744  0.500990      0.136735  United States
# 3  2003  0.015865  0.025521  0.002865  0.492720      0.134243  United States
# 4  2004  0.014968  0.024914  0.002855  0.448132      0.122717  United States
#
#                                    Variable                       Unit  \
# 0  Mortality from exposure to outdoor PM2.5  Per 1 000 000 inhabitants
# 1  Mortality from exposure to outdoor PM2.5  Per 1 000 000 inhabitants
# 2  Mortality from exposure to outdoor PM2.5  Per 1 000 000 inhabitants
# 3  Mortality from exposure to outdoor PM2.5  Per 1 000 000 inhabitants
# 4  Mortality from exposure to outdoor PM2.5  Per 1 000 000 inhabitants
#
#       Value
# 0  362.2790
# 1  361.3241
# 2  359.6222
# 3  355.1779
# 4  342.3452

# %%
merge_table.to_csv("../DataFrames/merged_set_data.csv", header=True)

# %%
plt.plot(merge_table['Year'], merge_table['Year Average'], marker='o')
plt.title("Mean Pollutant vs Year")
plt.xlabel("Year")
plt.ylabel("Year Average")
plt.grid()

# %%
plt.plot(merge_table['Year'], merge_table['Value'], marker='o')
plt.title("Avg Mort Count vs Year")
plt.xlabel("Year")
plt.ylabel("Avg Mort Count")
plt.grid()

# %%
#Drop additional 'Unnamed' column
nState_Population_df = State_Population_df.drop(columns='Unnamed: 0')
nState_Population_df
# Out:
#    Year  Year Pullutant Average  Year Mort Count  Alabama Population  \
# 0  2010                0.091656         306.2926           4712651.0
# 1  2011                0.087565         316.7458           4747424.0
# 2  2012                0.084872         298.2415           4777326.0
# 3  2013                0.078813         291.0552           4799277.0
# 4  2014                0.078189         277.7249           4817678.0
# 5  2015                0.079513         276.3403           4830620.0
# 6  2016                0.081310         259.2433           4841164.0
#
#    Alaska Population  Arizona Population  Arkansas Population  \
# 0           691189.0           6246816.0            2872684.0
# 1           700703.0           6337373.0            2895928.0
# 2           711139.0           6410979.0            2916372.0
# 3           720316.0           6479703.0            2933369.0
# 4           728300.0           6561516.0            2947036.0
# 5           733375.0           6641928.0            2958208.0
# 6           736855.0           6728577.0            2968472.0
#
#    California Population  Colorado Population  Connecticut Population  \
# 0             36637290.0            4887061.0               3545837.0
# 1             36969200.0            4966061.0               3558172.0
# 2             37325068.0            5042853.0               3572213.0
# 3             37659181.0            5119329.0               3583561.0
# 4             38066920.0            5197580.0               3592053.0
# 5             38421464.0            5278906.0               3593222.0
# 6             38654206.0            5359295.0               3588570.0
#
#                ...               Texas Population  Utah Population  \
# 0              ...                     24311891.0        2657236.0
# 1              ...                     24774187.0        2715379.0
# 2              ...                     25208897.0        2766233.0
# 3              ...                     25639373.0        2813673.0
# 4              ...                     26092033.0        2858111.0
# 5              ...                     26538614.0        2903379.0
# 6              ...                     26956435.0        2948427.0
#
#    Vermont Population  Virginia Population  Washington Population  \
# 0            624258.0            7841754.0              6561297.0
# 1            624958.0            7926192.0              6652845.0
# 2            625498.0            8014955.0              6738714.0
# 3            625904.0            8100653.0              6819579.0
# 4            626358.0            8185131.0              6899123.0
# 5            626604.0            8256630.0              6985464.0
# 6            626249.0            8310301.0              7073146.0
#
#    Washington, DC Population  West Virginia Population  Wisconsin Population  \
# 0                   584400.0                 1840802.0             5637947.0
# 1                   593955.0                 1846372.0             5664893.0
# 2                   605759.0                 1850481.0             5687219.0
# 3                   619371.0                 1853619.0             5706871.0
# 4                   633736.0                 1853881.0             5724692.0
# 5                   647484.0                 1851420.0             5742117.0
# 6                   659009.0                 1846092.0             5754798.0
#
#    Wyoming Population  Total US Population Estimate
# 0            545579.0                   307727594.0
# 1            554697.0                   310346358.0
# 2            562803.0                   312855438.0
# 3            570134.0                   315219560.0
# 4            575251.0                   317746049.0
# 5            579679.0                   320098094.0
# 6            583029.0                   322087547.0
#
# [7 rows x 56 columns]

# %%
plt.plot(nState_Population_df['Total US Population Estimate'], nState_Population_df['Year Pullutant Average'], marker='o')
plt.title("Population vs Pollution Average")
plt.xlabel("Population")
plt.ylabel("Pollution Average")
plt.grid()
#This graph shows a decrease US pollution average over time coressponding to an increase in US population over time.
#Note the correlation between these two my need to be explained carefully. As we know population tends to increase over time 
# and we have data that shows pollution average decreases overtime (For various reasons).

# %%
Mort_percentage = nState_Population_df['Year Mort Count'] / nState_Population_df['Total US Population Estimate']

# %%
plt.plot(nState_Population_df['Total US Population Estimate'], Mort_percentage, marker='o')
plt.title("Population vs Percentage Mortality From Air Pollution")
plt.xlabel("Population")
plt.ylabel("Percentage Mortality From Air Pollution")
plt.grid()
#

# %%
#A good analysis might be state population vs State pollutant levels each year for some states

# %%
# nChem_by_ST_Year = Chem_by_ST_Year.set_index(['Year', 'State'])
# nChem_by_ST_Year.head()

# %%
#Get DataFrame for the csv of Pollutant means grouped by 'State' then 'Year'
Group_State_then_Year.head()
# Out:
#      State  Year  NO2 Mean   O3 Mean  SO2 Mean   CO Mean  Year Average
# 0  Alabama  2013  0.012066  0.012099  0.000772  0.211873      0.059202
# 1  Alabama  2014  0.009412  0.024633  0.001198  0.206144      0.060347
# 2  Alabama  2015  0.009079  0.024000  0.001028  0.221390      0.063874
# 3  Alabama  2016  0.009525  0.028348  0.000859  0.210097      0.062207
# 4   Alaska  2014  0.011659  0.010307  0.005956  0.455232      0.120788

# %%
#Note when you first aqcuire data from csv the info is not longer index in the groupby format
#to reacquire groupby index format use set_index function
ST_YR_df = Group_State_then_Year.set_index(['State', 'Year'])
ST_YR_df.head()
# Out:
#               NO2 Mean   O3 Mean  SO2 Mean   CO Mean  Year Average
# State   Year
# Alabama 2013  0.012066  0.012099  0.000772  0.211873      0.059202
#         2014  0.009412  0.024633  0.001198  0.206144      0.060347
#         2015  0.009079  0.024000  0.001028  0.221390      0.063874
#         2016  0.009525  0.028348  0.000859  0.210097      0.062207
# Alaska  2014  0.011659  0.010307  0.005956  0.455232      0.120788

# %%
#Note loc function called with outer index on the multi-index dataframe will produce 'mini' (subset) dataframe indexed by the inner index 
#For example:
ST_YR_df.loc['Alabama']
#Creates a 'mini' df for Alabama with all the columns. Note the index in this case will be the 'Year' values for Alabama
# Out:
#       NO2 Mean   O3 Mean  SO2 Mean   CO Mean  Year Average
# Year
# 2013  0.012066  0.012099  0.000772  0.211873      0.059202
# 2014  0.009412  0.024633  0.001198  0.206144      0.060347
# 2015  0.009079  0.024000  0.001028  0.221390      0.063874
# 2016  0.009525  0.028348  0.000859  0.210097      0.062207

# %%
#To create a graph for Alabama info we first reset the index of our 'mini'(subset) Dataframe
Alabama_poll_data = ST_YR_df.loc['Alabama'].reset_index()
Alabama_poll_data
# Out:
#    Year  NO2 Mean   O3 Mean  SO2 Mean   CO Mean  Year Average
# 0  2013  0.012066  0.012099  0.000772  0.211873      0.059202
# 1  2014  0.009412  0.024633  0.001198  0.206144      0.060347
# 2  2015  0.009079  0.024000  0.001028  0.221390      0.063874
# 3  2016  0.009525  0.028348  0.000859  0.210097      0.062207

# %%
#we then merge the Alabama pollution DataFrame with the 'Year' and 'Alabama Population' columns Dataframe 
#Made from our State population dataframe
Alabama_Data = pd.merge(Alabama_poll_data, nState_Population_df[['Year', 'Alabama Population']], on="Year")

# %%
Alabama_Data
# Out:
#    Year  NO2 Mean   O3 Mean  SO2 Mean   CO Mean  Year Average  \
# 0  2013  0.012066  0.012099  0.000772  0.211873      0.059202
# 1  2014  0.009412  0.024633  0.001198  0.206144      0.060347
# 2  2015  0.009079  0.024000  0.001028  0.221390      0.063874
# 3  2016  0.009525  0.028348  0.000859  0.210097      0.062207
#
#    Alabama Population
# 0           4799277.0
# 1           4817678.0
# 2           4830620.0
# 3           4841164.0

# %%
plt.subplot(1,1,1)
plt.plot(Alabama_Data['Alabama Population'],Alabama_Data['NO2 Mean'],marker='o')
plt.title("Change Over Time")
plt.xlabel("Population")
plt.ylabel("NO2 Mean")
plt.grid()
plt.show()

plt.subplot()
plt.plot(Alabama_Data['Alabama Population'],Alabama_Data['O3 Mean'],marker='^')
plt.title("Change Over Time")
plt.xlabel("Population")
plt.ylabel("O3 Mean")
plt.grid()
plt.show()

plt.subplot()
plt.plot(Alabama_Data['Alabama Population'],Alabama_Data['SO2 Mean'],marker='*')
plt.title("Change Over Time")
plt.xlabel("Population")
plt.ylabel("SO2 Mean")
plt.grid()
plt.show()

plt.subplot(4,1,1)
plt.plot(Alabama_Data['Alabama Population'],Alabama_Data['CO Mean'],marker='.')
plt.title("Change Over Time")
plt.xlabel("Population")
plt.ylabel("CO Mean'")
plt.grid()
plt.show()

# %%
nWorld_Pollution_df = World_Pollution_df.drop(columns='Unnamed: 0')
nWorld_Pollution_df.head()
# Out:
#        City    Country   Latitude  Longitude  Value CO  Value NO2  Value O3  \
# 0    Tandil  Argentina -37.321674 -59.133164         0          0        17
# 1   Ushuaia  Argentina -54.800000 -68.300000         0          0        12
# 2  Villazon  Argentina -22.100000 -65.600000         0          0         5
# 3   Mendoza  Argentina -32.890845 -68.827171         1          8        11
# 4    Tandil  Argentina -37.321674 -59.133164         0          0        23
#
#    Value PM25
# 0           7
# 1           4
# 2           5
# 3          54
# 4          23

# %%
fig = gmaps.figure()
heatmap_layer = gmaps.heatmap_layer(
    nWorld_Pollution_df[['Latitude', 'Longitude']], weights=nWorld_Pollution_df['Value NO2'],
    max_intensity=30, point_radius=3.0
)
fig.add_layer(heatmap_layer)
fig
